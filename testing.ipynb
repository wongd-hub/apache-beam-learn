# %%
# !source bin/activate > /dev/null # This suppresses cell output by redirecting it
# %pip install -r requirements.txt > /dev/null
# Out:
# WARNING: You are using pip version 22.0.4; however, version 23.3 is available.
# You should consider upgrading via the '/Users/darrenwong/Documents/Projects/apache-beam-learn/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Simple wordcount example - Direct runner

# %%
# !python -m source.wordcount --input input/agatha_complete.txt --output output/agatha_count.txt
# Out:
# INFO:root:Missing pipeline option (runner). Executing pipeline using the default runner: DirectRunner.
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function annotate_downstream_side_inputs at 0x7fe413837160> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function fix_side_input_pcoll_coders at 0x7fe413837280> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function pack_combiners at 0x7fe413837790> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function lift_combiners at 0x7fe413837820> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function expand_sdf at 0x7fe4138379d0> ====================
# ...

# %%
# !cat output/agatha_count.txt-00000-of-00001
# Out:
# From: 1
# https: 1
# github: 1
# com: 1
# itsfoss: 1
# text: 1
# files: 1
# blob: 1
# master: 1
# agatha_complete: 1
# txt: 1
# The: 34
# ABC: 1
# Murders: 3
# 1936: 3
# Adventure: 1
# of: 10
# the: 19
# Christmas: 2
# Pudding: 1
# 1960: 1
# After: 2
# Funeral: 1
# also: 24
# known: 24
# as: 24
# Funerals: 1
# are: 1
# Fatal: 1
# 1953: 2
# And: 1
# Then: 1
# There: 2
# Were: 1
# None: 1
# Ten: 2
# Little: 3
# Indians: 1
# and: 6
# Niggers: 1
# 1939: 3
# Appointment: 1
# with: 2
# Death: 9
# 1938: 2
# At: 4
# Bertram: 1
# s: 8
# Hotel: 1
# 1965: 1
# Big: 1
# Four: 1
# 1927: 1
# Body: 1
# in: 7
# Library: 1
# 1942: 1
# By: 1
# Pricking: 1
# my: 1
# Thumbs: 1
# 1968: 1
# Cards: 1
# on: 5
# Table: 1
# A: 4
# Caribbean: 1
# Mystery: 7
# 1964: 1
# Cat: 1
# Among: 1
# Pigeons: 1
# 1959: 1
# Clocks: 1
# 1963: 1
# Crooked: 1
# House: 3
# 1949: 1
# Curtain: 1
# Poirot: 5
# Last: 1
# Case: 1
# 1975: 1
# Dead: 3
# Man: 3
# Folly: 1
# 1956: 1
# Comes: 1
# End: 2
# 1945: 2
# Clouds: 1
# In: 3
# ...

# %% [markdown]
# ## Simple wordcount example - GCP Dataflow runner

# %%
# %%bash
#
# # Add GCP Service Account credentials to env vars
# export GOOGLE_APPLICATION_CREDENTIALS="secrets/test-project-401023-97e34d2a632a.json"
#
# # Run sample pipeline
# python -m source.wordcount --input gs://dataflow-samples/shakespeare/kinglear.txt \
#                            --output gs://ds-edw-raw-f9819bf2/counts \
#                            --runner DataflowRunner \
#                            --project test-project-401023 \
#                            --region australia-southeast1 \
#                            --temp_location gs://ds-edw-raw-f9819bf2/tmp/
# Out:
# INFO:apache_beam.internal.gcp.auth:Setting socket default timeout to 60 seconds.
# INFO:apache_beam.internal.gcp.auth:socket default timeout is 60.0 seconds.
# INFO:apache_beam.runners.dataflow.dataflow_runner:Pipeline has additional dependencies to be installed in SDK worker container, consider using the SDK container image pre-building workflow to avoid repetitive installations. Learn more on https://cloud.google.com/dataflow/docs/guides/using-custom-containers#prebuild
# INFO:root:Using provided Python SDK container image: gcr.io/cloud-dataflow/v1beta3/beam_python3.9_sdk:2.51.0
# INFO:root:Python SDK container image set to "gcr.io/cloud-dataflow/v1beta3/beam_python3.9_sdk:2.51.0" for Docker environment
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function pack_combiners at 0x7fb00b9451f0> ====================
# ...
